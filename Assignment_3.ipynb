# %% [markdown]
# <a href="https://colab.research.google.com/github/sati99/SHALA2020/blob/master/Assignment_3.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # **Assignment - 3: Improving Graphs**
#
# ---
# Course website: [SHALA-2020](https://shala2020.github.io/)
#
# This assignment will get you familiarized with improving plots/graphs in Python.

# %% [markdown]
# ---
# ## Part 1 - Importing packages and loading data
# ---

# %% [markdown]
# ###Import the following libraries:
#
# * ```numpy``` with an alias name ```np```,
# * ```pandas``` with an alias name ```pd```,
# * ```matplotlib.pyplot``` with an alias name ```plt```, and
# * ```seaborn``` with an alias name ```sns```.
#
# *You are free to use any other popular libraries*.

# %%
# Load the libraries with their aliases 
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
# Out:
# /usr/local/lib/python3.6/dist-packages/statsmodels/tools/_testing.py:19: FutureWarning: pandas.util.testing is deprecated. Use the functions in the public API at pandas.testing instead.
#   import pandas.util.testing as tm

# %% [markdown]
# ### Using the files ```train.csv``` and ```moviesData.csv```,  peform the following:
#
# * Load these file as ```pandas``` dataframes and store it in variables named ```train``` and ```movies``` respectively.
# * Print the first ten rows of ```train``` and last ten rows of ```movies```.

# %%
# Load train.csv and movies.csv 
url_train = "https://raw.githubusercontent.com/shala2020/shala2020.github.io/master/Lecture_Materials/Assignments/DataScience/L2/train.csv"
train = pd.read_csv('train.csv')

# Print the first ten rows of train
train.head(10)
# Out:
#    Age  Attrition  ... YearsWithCurrManager  ID
# 0   41          1  ...                    5   0
# 1   49          0  ...                    7   1
# 2   37          1  ...                    0   2
# 3   33          0  ...                    0   3
# 4   27          0  ...                    2   4
# 5   32          0  ...                    6   5
# 6   59          0  ...                    0   6
# 7   30          0  ...                    0   7
# 8   38          0  ...                    8   8
# 9   36          0  ...                    7   9
#
# [10 rows x 34 columns]

# %%
# Load movies.csv
url_movies = "https://raw.githubusercontent.com/shala2020/shala2020.github.io/master/Lecture_Materials/Google_Colab_Notebooks/DataScience/L2/moviesData.csv"
movies = pd.read_csv('moviesData.csv')

# Print the last ten rows of movies 
movies.tail(10)
# Out:
#      Unnamed: 0  ...            actor5
# 590         591  ...        Ben Vereen
# 591         592  ...       Bob Balaban
# 592         593  ...     George Gaynes
# 593         594  ...   Lance Henriksen
# 594         595  ...  Steve Guttenberg
# 595         596  ...       Jack Bailey
# 596         597  ...       Rachel True
# 597         598  ...    Randy McDowell
# 598         599  ...       Ian McNeice
# 599         600  ...    Adam G. Sevani
#
# [10 rows x 31 columns]

# %% [markdown]
# ---
# ## Part 2 - Drawing correlation and heatmap
# ---

# %% [markdown]
# ### Using the correlation matrix, peform the following:
#
# * Find the correlation matrix for the ```movies```.
# * Draw a **heatmap** with the correlation matrix and display the values of correlation coefficients for each pair of features. Make sure the values are properly visible. You might want to adjust the figure size for this.
# * Create a ```mask``` to remove the duplicate values from the **heatmap**.

# %%
# Find out the correlation matrix 
movies.corr()
# Out:
#                 Unnamed: 0   runtime  ...  critics_score  audience_score
# Unnamed: 0        1.000000 -0.045146  ...       0.003937        0.012582
# runtime          -0.045146  1.000000  ...       0.169494        0.172237
# thtr_rel_year    -0.000639 -0.124754  ...      -0.096445       -0.062610
# thtr_rel_month    0.005468  0.215274  ...       0.047717        0.034901
# thtr_rel_day      0.046227  0.033998  ...       0.023837        0.033812
# dvd_rel_year     -0.000382 -0.088603  ...       0.009554       -0.073794
# dvd_rel_month    -0.015944 -0.036916  ...       0.041502        0.070543
# dvd_rel_day       0.024857  0.021001  ...      -0.024717        0.019294
# imdb_rating       0.027596  0.261153  ...       0.770764        0.865149
# imdb_num_votes    0.045508  0.342462  ...       0.200657        0.288328
# critics_score     0.003937  0.169494  ...       1.000000        0.710695
# audience_score    0.012582  0.172237  ...       0.710695        1.000000
#
# [12 rows x 12 columns]

# %%
# Draw the heatmap 
plt.figure(figsize=(12,12))
sns.heatmap(movies.corr(),annot= True,cmap='coolwarm')

# %%
# Creating a mask for removing duplicates 
mask = np.zeros_like(movies.corr(), dtype=np.bool)
mask[np.triu_indices_from(mask)]= True
plt.figure(figsize=(12,12))
heatmap = sns.heatmap(movies.corr(), vmin=-1, vmax=1, mask=mask, square=True,cmap='coolwarm',linewidths = .5,annot=True ,annot_kws = {'size': 6})

# %% [markdown]
# ---
# ## Part 3 - Drawing plots and customizing these
# ---

# %% [markdown]
# ### Using a histogram, peform the following:
#
# * Draw a histogram of all the numeric features in ```train```. Please note that this can be done in a single command.
#
# * Find out whether there is any redundant features in ```train```, which can be dropped while building a model.

# %%
# Draw a histogram 
train.hist(figsize=(16,16))
# Out:
# array([[<matplotlib.axes._subplots.AxesSubplot object at 0x7fddc7c1b8d0>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x7fddc7b6fba8>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x7fddc7ba3e10>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x7fddc7b85550>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x7fddc7af77f0>],
#        [<matplotlib.axes._subplots.AxesSubplot object at 0x7fddc7aaaa58>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x7fddc7adfcc0>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x7fddc7a93ef0>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x7fddc7a93f60>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x7fddc7a06438>],
#        [<matplotlib.axes._subplots.AxesSubplot object at 0x7fddc79bb6a0>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x7fddc796d908>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x7fddc79a1b70>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x7fddc7952dd8>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x7fddc7916080>],
#        [<matplotlib.axes._subplots.AxesSubplot object at 0x7fddc78c72e8>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x7fddc787b550>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x7fddc782e7b8>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x7fddc7861a20>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x7fddc7814c88>],
#        [<matplotlib.axes._subplots.AxesSubplot object at 0x7fddc77c7ef0>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x7fddc7789198>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x7fddc773a400>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x7fddc76ef668>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x7fddc77218d0>],
#        [<matplotlib.axes._subplots.AxesSubplot object at 0x7fddc76d6b38>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x7fddc768ada0>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x7fddc763bfd0>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x7fddc75fd2b0>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x7fddc75af518>]],
#       dtype=object)

# %%
# Find out the redundant features 
Attrition n Job Level.

# %% [markdown]
# ### Using a scatter plot, perform the following:
#
# * Draw a scatter plot between between ```imdb_rating``` and ```audience_score```, and also fit a regression line.
# * Change the color of marker to red, size to 200, transparency to 0.3.

# %%
# Scatter plot to fit the regression line 
 sns.regplot(x='imdb_rating',y='audience_score',data=movies,color='Cyan')

# %%
# Change marker of the scatter plot
sns.regplot(x='imdb_rating', y='audience_score',data=movies,color='Cyan', scatter_kws={'color':'red','alpha':0.3,'s':200})

# %% [markdown]
# ### Using a scatter plot, perform the following:
#
# * Load the dataset ```iris```. This has been done for you.
# * Draw a scatter plot between between ```petal_length``` and ```petal_width``` and color it according to the ```species```.
# * Change the size of marker to 100 and place the legend in ```lower right```.

# %%
# library & dataset
import seaborn as sns
df = sns.load_dataset('iris')

# %%
# Use the 'hue' argument to provide a factor variable
sns.lmplot(x="sepal_length", y="sepal_width", data=df, fit_reg=False, hue='species', legend=False)

# Move the legend to an empty part of the plot
plt.legend(loc='lower right')

# %% [markdown]
# ---
# ## Part 4 - Density Plots
# ---

# %% [markdown]
# ### Using density plots, perform the following:
#
# * Load the dataset ```iris```. This has been done for you.
# * Draw the density plots for all the features ```sepal_width```, ```sepal_length```, ```petal_width```, and ```petal_length```. You can required to use subplots for plotting all the density plots.
# * Try drawing a [CDF](https://en.wikipedia.org/wiki/Cumulative_distribution_function) of these features. There is a [blog on medium](https://medium.com/@rishav.jnit/exploratory-data-analysis-eda-on-iris-dataset-using-python-cadd850c1fc6) on how to plot CDF. It will be covered in tutorial.

# %%
# library and dataset 
from pylab import*
df = sns.load_dataset('iris')

# %%
#CDF
subplot(2,2,1)
sns.kdeplot(df['sepal_width'],shade= True,color='Red',cumulative=True)

subplot(2,2,2)
sns.kdeplot(df['sepal_length'],shade= True,color='Yellow',cumulative=True)

subplot(2,2,3)
sns.kdeplot(df['petal_width'],shade= True,color='Green',cumulative=True)

subplot(2,2,4)
sns.kdeplot(df['petal_length'],shade= True,color='Blue',cumulative=True)

# %%
subplot(2,2,1)
sns.kdeplot(df['sepal_width'],shade= True,Color ='Red')

subplot(2,2,2)
sns.kdeplot(df['sepal_length'],shade= True,Color ='Yellow')

subplot(2,2,3)
sns.kdeplot(df['petal_width'],shade= True,Color ='Green')

subplot(2,2,4)
sns.kdeplot(df['petal_length'],shade= True,Color ='Blue')

# %% [markdown]
# ### Using violin plot, perform the following:
#
# * Load the dataset ```iris```. This has been done for you.
# * Draw the density plots of ```species``` versus ```sepal_length```.
# * Assign each group a color like
#
#     * versicolor - green,
#     * setosa - blue,
#     * virginica - m

# %%
# Draw the normal violin plots 
sns.violinplot(x=df["species"], y=df["sepal_length"])

# %%
# Change the color of each group 
sns.violinplot(x=df['species'],y=df['sepal_length'], palette=('Blue','Green','m'))
